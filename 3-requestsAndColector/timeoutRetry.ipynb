# %% [markdown]
# É comum no desenvolvimento integrarmos com serviços parceiros, isso ocorre geralmente por meio de APIs
# É recomendado, um requisito que na aplicação tenhamos uma boa politica de timeout e de retry
# Em docker e kubernetes ja existem aplicações de baixo nivel que abstraem esse tipo de politica, mas é de cenário pra cenário.
# por isso é bom saber implementar isso em python

# %% [markdown]
# vamos gerar um projeto com poetry que é um gerenciador de pacotes py
